# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('AirQualityodisha.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv('AirQualityodisha.csv')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
df.isnull().sum()
# Out:
# Stn Code                            0
# Sampling Date                       0
# State                               0
# City                                0
# Location of Monitoring Station      0
# Agency                              0
# Type of Location                    0
# SO2                                 0
# NO2                                 0
# RSPM/PM10                           0
# PM 2.5                            332
# dtype: int64

# %%
df.dropna()
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
df.drop_duplicates()
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
#df.fillna(0)#replace missing value with 0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Stn Code, Sampling Date, State, City, Location of Monitoring Station, Agency, Type of Location, SO2, NO2, RSPM/PM10, PM 2.5]
# Index: []

# %%
df1=df.loc[0:100]

# %%
df1
# Out:
#      Stn Code Sampling Date State City Location of Monitoring Station Agency  \
# 0          68           NaN   NaN  NaN                            NaN    NaN
# 1          68           NaN   NaN  NaN                            NaN    NaN
# 2          68           NaN   NaN  NaN                            NaN    NaN
# 3          68           NaN   NaN  NaN                            NaN    NaN
# 4          68           NaN   NaN  NaN                            NaN    NaN
# ..        ...           ...   ...  ...                            ...    ...
# 96         70           NaN   NaN  NaN                            NaN    NaN
# 97         70           NaN   NaN  NaN                            NaN    NaN
# 98         70           NaN   NaN  NaN                            NaN    NaN
# 99         70           NaN   NaN  NaN                            NaN    NaN
# 100        70           NaN   NaN  NaN                            NaN    NaN
#
# ...

# %%
df2=df[101:201]

# %%
df2
# Out:
#      Stn Code Sampling Date State City Location of Monitoring Station Agency  \
# 101        70           NaN   NaN  NaN                            NaN    NaN
# 102        70           NaN   NaN  NaN                            NaN    NaN
# 103        70           NaN   NaN  NaN                            NaN    NaN
# 104        70           NaN   NaN  NaN                            NaN    NaN
# 105        70           NaN   NaN  NaN                            NaN    NaN
# ..        ...           ...   ...  ...                            ...    ...
# 196       227           NaN   NaN  NaN                            NaN    NaN
# 197       227           NaN   NaN  NaN                            NaN    NaN
# 198       227           NaN   NaN  NaN                            NaN    NaN
# 199       227           NaN   NaN  NaN                            NaN    NaN
# 200       227           NaN   NaN  NaN                            NaN    NaN
#
# ...

# %%
fr=[df1,df2]
result=pd.concat(fr)
print(result)
# Out:
#      Stn Code Sampling Date State City Location of Monitoring Station Agency  \
# 0          68           NaN   NaN  NaN                            NaN    NaN
# 1          68           NaN   NaN  NaN                            NaN    NaN
# 2          68           NaN   NaN  NaN                            NaN    NaN
# 3          68           NaN   NaN  NaN                            NaN    NaN
# 4          68           NaN   NaN  NaN                            NaN    NaN
# ..        ...           ...   ...  ...                            ...    ...
# 196       227           NaN   NaN  NaN                            NaN    NaN
# 197       227           NaN   NaN  NaN                            NaN    NaN
# 198       227           NaN   NaN  NaN                            NaN    NaN
# 199       227           NaN   NaN  NaN                            NaN    NaN
# 200       227           NaN   NaN  NaN                            NaN    NaN
#
# ...

# %%
merge1=pd.merge(df1,df2,on='Stn Code',how='inner')#data integration

# %%
merge1
# Out:
#       Stn Code Sampling Date_x State_x City_x  \
# 0           70             NaN     NaN    NaN
# 1           70             NaN     NaN    NaN
# 2           70             NaN     NaN    NaN
# 3           70             NaN     NaN    NaN
# 4           70             NaN     NaN    NaN
# ...        ...             ...     ...    ...
# 2739        70             NaN     NaN    NaN
# 2740        70             NaN     NaN    NaN
# 2741        70             NaN     NaN    NaN
# 2742        70             NaN     NaN    NaN
# 2743        70             NaN     NaN    NaN
#
#      Location of Monitoring Station_x Agency_x Type of Location_x  SO2_x  \
# 0                                 NaN      NaN                NaN      7
# 1                                 NaN      NaN                NaN      7
# 2                                 NaN      NaN                NaN      7
# 3                                 NaN      NaN                NaN      7
# ...

# %%
#data transformation

# %%
#scaling numerical variable ....value is transform to value between 0-1
num_col=['SO2_y','NO2_y']
merge1[num_col]=merge1[num_col]/merge1[num_col].max()

# %%
merge1[num_col]
# Out:
#          SO2_y     NO2_y
# 0     0.692308  0.758621
# 1     0.923077  0.896552
# 2     1.000000  0.931034
# 3     0.846154  0.896552
# 4     0.769231  0.862069
# ...        ...       ...
# 2739  0.692308  0.793103
# 2740  0.692308  0.896552
# 2741  0.769231  0.931034
# 2742  0.769231  0.827586
# 2743  1.000000  1.000000
#
# [2744 rows x 2 columns]

# %%
#encoding categorical variable
categorical_col=['State_y','City_y']
merge1=pd.get_dummies(merge1,columns=categorical_col)#represent categorical data in numerical format

# %%
merge1
# Out:
#       Stn Code Sampling Date_x State_x City_x  \
# 0           70             NaN     NaN    NaN
# 1           70             NaN     NaN    NaN
# 2           70             NaN     NaN    NaN
# 3           70             NaN     NaN    NaN
# 4           70             NaN     NaN    NaN
# ...        ...             ...     ...    ...
# 2739        70             NaN     NaN    NaN
# 2740        70             NaN     NaN    NaN
# 2741        70             NaN     NaN    NaN
# 2742        70             NaN     NaN    NaN
# 2743        70             NaN     NaN    NaN
#
#      Location of Monitoring Station_x Agency_x Type of Location_x  SO2_x  \
# 0                                 NaN      NaN                NaN      7
# 1                                 NaN      NaN                NaN      7
# 2                                 NaN      NaN                NaN      7
# 3                                 NaN      NaN                NaN      7
# ...

# %%
merge1['Sampling Date_x']=pd.to_datetime(merge1['Sampling Date_y'])

# %%
merge1
# Out:
#       Stn Code Sampling Date_x State_x City_x  \
# 0           70             NaT     NaN    NaN
# 1           70             NaT     NaN    NaN
# 2           70             NaT     NaN    NaN
# 3           70             NaT     NaN    NaN
# 4           70             NaT     NaN    NaN
# ...        ...             ...     ...    ...
# 2739        70             NaT     NaN    NaN
# 2740        70             NaT     NaN    NaN
# 2741        70             NaT     NaN    NaN
# 2742        70             NaT     NaN    NaN
# 2743        70             NaT     NaN    NaN
#
#      Location of Monitoring Station_x Agency_x Type of Location_x  SO2_x  \
# 0                                 NaN      NaN                NaN      7
# 1                                 NaN      NaN                NaN      7
# 2                                 NaN      NaN                NaN      7
# 3                                 NaN      NaN                NaN      7
# ...

# %%
#...............ERROR CORRECTING.............

# %%
#removing duplicates in numerical variable using z_score
num_col=['Stn Code','SO2','NO2']
z_score=pd.DataFrame((df[num_col]-df[num_col].mean())/df[num_col].std())
outliers=(z_score>10)
df3=df[~outliers]

# %%
df3
# Out:
#       Stn Code Sampling Date State City Location of Monitoring Station Agency  \
# 0           68           NaN   NaN  NaN                            NaN    NaN
# 1           68           NaN   NaN  NaN                            NaN    NaN
# 2           68           NaN   NaN  NaN                            NaN    NaN
# 3           68           NaN   NaN  NaN                            NaN    NaN
# 4           68           NaN   NaN  NaN                            NaN    NaN
# ...        ...           ...   ...  ...                            ...    ...
# 2387       819           NaN   NaN  NaN                            NaN    NaN
# 2388       819           NaN   NaN  NaN                            NaN    NaN
# 2389       819           NaN   NaN  NaN                            NaN    NaN
# 2390       819           NaN   NaN  NaN                            NaN    NaN
# 2391       819           NaN   NaN  NaN                            NaN    NaN
#
# ...

# %%
df5=pd.read_csv('heart.csv')
df5
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X=df5.drop(columns='target')
y=df5['target']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
model=LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model=LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y_pred=model.predict(X_test)
#
# NameError: name 'model' is not defined

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 0.11063885351374454

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.556589946698921
