# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('../Graph/AirQualityodisha.csv')
df2 = pd.read_csv('../Graph/Heart2.csv')
df3 = pd.read_csv('../Graph/forestfires.csv')

# %%
df1
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
df2
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df3
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
df1.shape
# Out:
# (2392, 11)

# %%
df2.shape
# Out:
# (303, 15)

# %%
df3.shape
# Out:
# (517, 13)

# %%
---LINEPLOT-----

# %%
df1.head()
# Out:
#    Stn Code Sampling Date   State     City Location of Monitoring Station  \
# 0        68      02-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 1        68      06-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 2        68      09-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 3        68      13-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
# 4        68      16-01-15  Odisha  Talcher        T.T.P.S.Colony, Talcher
#
#                                  Agency Type of Location  SO2  NO2  RSPM/PM10  \
# 0  Odisha State Pollution Control Board  Industrial Area   11   24        143
# 1  Odisha State Pollution Control Board  Industrial Area   10   23        133
# 2  Odisha State Pollution Control Board  Industrial Area    8   25        125
# 3  Odisha State Pollution Control Board  Industrial Area   10   25        137
# 4  Odisha State Pollution Control Board  Industrial Area    9   26        186
#
#    PM 2.5
# 0   102.0
# 1    96.0
# 2   116.0
# ...

# %%
sns.lineplot(data=df1)
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
sns.lineplot(data=df2)
# Out:
# <Axes: >

# %%
df3.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
sns.lineplot(data=df3)
# Out:
# <Axes: >

# %%
BARPLOT

# %%
x = df1['NO2']
y = df1['SO2']
sns.barplot(x=df1['NO2'], y=df1['SO2'])
# Out:
# <Axes: xlabel='NO2', ylabel='SO2'>

# %%
x = df2['Age']
y = df2['Sex']
sns.barplot(x=df2['Age'], y=df2['Sex'])
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
x = df3['month']
y = df3['temp']
sns.barplot(x=df3['month'], y=df3['temp'])
# Out:
# <Axes: xlabel='month', ylabel='temp'>

# %%
SCATTERPLOT

# %%
sns.scatterplot(x=df1['NO2'],y=df1['SO2'])
# Out:
# <Axes: xlabel='NO2', ylabel='SO2'>

# %%
sns.scatterplot(x=df2['Age'],y=df2['Sex'])
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sns.scatterplot(x=df3['month'],y=df3['temp'])
# Out:
# <Axes: xlabel='month', ylabel='temp'>

# %%
BARPLOT---

# %%
plt.hist(df1['RSPM/PM10'])
# Out:
# (array([8.500e+02, 1.265e+03, 2.460e+02, 2.000e+01, 3.000e+00, 4.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00]),
#  array([ 15. ,  72.5, 130. , 187.5, 245. , 302.5, 360. , 417.5, 475. ,
#         532.5, 590. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df2['MaxHR'])
# Out:
# (array([ 1.,  6., 11., 26., 35., 53., 78., 62., 26.,  5.]),
#  array([ 71. ,  84.1,  97.2, 110.3, 123.4, 136.5, 149.6, 162.7, 175.8,
#         188.9, 202. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df3['temp'])
# Out:
# (array([ 18.,  11.,  31.,  47.,  92., 127.,  99.,  55.,  24.,  13.]),
#  array([ 2.2 ,  5.31,  8.42, 11.53, 14.64, 17.75, 20.86, 23.97, 27.08,
#         30.19, 33.3 ]),
#  <BarContainer object of 10 artists>)
